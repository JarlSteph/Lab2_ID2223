# %%
#http://localhost:6006/?darkMode=true#scalars&_smoothingWeight=0

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 31825), started 13:54:46 ago. (Use '!kill 31825' to kill it.)
#       <iframe id="tensorboard-frame-7150740eba6a44a3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7150740eba6a44a3");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
