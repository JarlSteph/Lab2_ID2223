# %%
#http://localhost:6006/?darkMode=true#scalars&_smoothingWeight=0

# %%
# !kill 81705

# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
# zsh:kill:1: kill 81705 failed: no such process
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 85238), started 0:00:13 ago. (Use '!kill 85238' to kill it.)
#       <iframe id="tensorboard-frame-932182dd91b61607" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-932182dd91b61607");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
